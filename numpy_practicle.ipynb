# %%
import numpy as np     #array

# %%
import matplotlib.pyplot as plt      #visualization

# %%
from PIL import Image     #python image library

# %%
Image = Image.open(r'/Users/mujeebmohammed/Desktop/pic.jpg')
Image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=531x560>

# %%
print(type(Image))
# Out:
# <class 'PIL.PngImagePlugin.PngImageFile'>

# %%
Image=np.asarray(Image)
Image
# Out:
# array([[[255, 233, 172, 255],
#         [255, 233, 172, 255],
#         [255, 233, 172, 255],
#         ...,
#         [255, 233, 172, 255],
#         [255, 233, 172, 255],
#         [255, 233, 172, 255]],
#
#        [[255, 233, 172, 255],
#         [255, 233, 172, 255],
#         [255, 233, 172, 255],
#         ...,
#         [255, 233, 172, 255],
#         [255, 233, 172, 255],
#         [255, 233, 172, 255]],
#
#        [[255, 233, 172, 255],
#         [255, 233, 172, 255],
#         [255, 233, 172, 255],
#         ...,
#         [255, 233, 172, 255],
#         [255, 233, 172, 255],
#         [255, 233, 172, 255]],
#
#        ...,
#
#        [[255, 233, 172, 255],
#         [255, 233, 172, 255],
#         [255, 233, 172, 255],
#         ...,
#         [237, 216, 170, 255],
#         [231, 209, 163, 255],
#         [226, 204, 157, 255]],
#
#        [[255, 233, 172, 255],
#         [255, 233, 172, 255],
#         [255, 233, 172, 255],
#         ...,
#         [253, 232, 177, 255],
# ...

# %%
plt.imshow(Image)
plt.show()

# %%
Image.shape
# Out:
# (560, 531, 4)
