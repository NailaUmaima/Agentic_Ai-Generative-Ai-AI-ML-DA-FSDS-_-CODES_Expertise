# %%
import pandas as pd

# %%
abc=pd.read_csv(r'/Users/mujeebmohammed/Downloads/abc.csv.xls')

# %%
abc
# Out:
#   student  language  science  maths  history
# 0   kumar        90       56     34       34
# 1   kevin        10       34     32       67
# 2   sammy        90       23     12       32
# 3  janice        20       67     90       45
# 4   peter        30       56     45       65
# 5    prem        90       45     45       34
# 6  carrol        50       90     45       23

# %%
abc.head()
# Out:
#   student  language  science  maths  history
# 0   kumar        90       56     34       34
# 1   kevin        10       34     32       67
# 2   sammy        90       23     12       32
# 3  janice        20       67     90       45
# 4   peter        30       56     45       65

# %%
abc.tail()
# Out:
#   student  language  science  maths  history
# 2   sammy        90       23     12       32
# 3  janice        20       67     90       45
# 4   peter        30       56     45       65
# 5    prem        90       45     45       34
# 6  carrol        50       90     45       23

# %%
abc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   student   7 non-null      object
#  1   language  7 non-null      int64
#  2   science   7 non-null      int64
#  3   maths     7 non-null      int64
#  4   history   7 non-null      int64
# dtypes: int64(4), object(1)
# memory usage: 412.0+ bytes

# %%
abc.describe()
# Out:
#         language    science      maths    history
# count   7.000000   7.000000   7.000000   7.000000
# mean   54.285714  53.000000  43.285714  42.857143
# std    35.523299  22.015146  23.746679  17.062909
# min    10.000000  23.000000  12.000000  23.000000
# 25%    25.000000  39.500000  33.000000  33.000000
# 50%    50.000000  56.000000  45.000000  34.000000
# 75%    90.000000  61.500000  45.000000  55.000000
# max    90.000000  90.000000  90.000000  67.000000

# %%
abc.describe().transpose()
# Out:
#           count       mean        std   min   25%   50%   75%   max
# language    7.0  54.285714  35.523299  10.0  25.0  50.0  90.0  90.0
# science     7.0  53.000000  22.015146  23.0  39.5  56.0  61.5  90.0
# maths       7.0  43.285714  23.746679  12.0  33.0  45.0  45.0  90.0
# history     7.0  42.857143  17.062909  23.0  33.0  34.0  55.0  67.0

# %%
abc.isna()
# Out:
#    student  language  science  maths  history
# 0    False     False    False  False    False
# 1    False     False    False  False    False
# 2    False     False    False  False    False
# 3    False     False    False  False    False
# 4    False     False    False  False    False
# 5    False     False    False  False    False
# 6    False     False    False  False    False

# %%
abc.isna().sum()
# Out:
# student     0
# language    0
# science     0
# maths       0
# history     0
# dtype: int64

# %%
abc.dtypes
# Out:
# student     object
# language     int64
# science      int64
# maths        int64
# history      int64
# dtype: object

# %%
abc['student']
# Out:
# 0     kumar
# 1     kevin
# 2     sammy
# 3    janice
# 4     peter
# 5      prem
# 6    carrol
# Name: student, dtype: object

# %%
abc[['language','maths']]
# Out:
#    language  maths
# 0        90     34
# 1        10     32
# 2        90     12
# 3        20     90
# 4        30     45
# 5        90     45
# 6        50     45

# %%
abc.head(2)
# Out:
#   student  language  science  maths  history
# 0   kumar        90       56     34       34
# 1   kevin        10       34     32       67

# %%
abc[['student','maths']][0:2]
# Out:
#   student  maths
# 0   kumar     34
# 1   kevin     32

# %%
abc[2:4][['student','maths']]
# Out:
#   student  maths
# 2   sammy     12
# 3  janice     90

# %%
abc.columns
# Out:
# Index(['student', 'language', 'science', 'maths', 'history'], dtype='object')

# %%
len(abc.columns)
# Out:
# 5

# %%
len(abc)
# Out:
# 7

# %%
abc.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
abc.columns=['a','b','c','d','e']

# %%
abc
# Out:
#         a   b   c   d   e
# 0   kumar  90  56  34  34
# 1   kevin  10  34  32  67
# 2   sammy  90  23  12  32
# 3  janice  20  67  90  45
# 4   peter  30  56  45  65
# 5    prem  90  45  45  34
# 6  carrol  50  90  45  23

# %%
abc.columns=['student','language','science','maths','history']

# %%
abc
# Out:
#   student  language  science  maths  history
# 0   kumar        90       56     34       34
# 1   kevin        10       34     32       67
# 2   sammy        90       23     12       32
# 3  janice        20       67     90       45
# 4   peter        30       56     45       65
# 5    prem        90       45     45       34
# 6  carrol        50       90     45       23

# %%
abc_numeric_data=abc[['language','science','maths','history']]
abc_numeric_data
# Out:
#    language  science  maths  history
# 0        90       56     34       34
# 1        10       34     32       67
# 2        90       23     12       32
# 3        20       67     90       45
# 4        30       56     45       65
# 5        90       45     45       34
# 6        50       90     45       23

# %%
abc_categorical_data=abc[['student']]
abc_categorical_data
# Out:
#   student
# 0   kumar
# 1   kevin
# 2   sammy
# 3  janice
# 4   peter
# 5    prem
# 6  carrol

# %%
abc.language
# Out:
# 0    90
# 1    10
# 2    90
# 3    20
# 4    30
# 5    90
# 6    50
# Name: language, dtype: int64

# %%
abc.maths
# Out:
# 0    34
# 1    32
# 2    12
# 3    90
# 4    45
# 5    45
# 6    45
# Name: maths, dtype: int64

# %%
abc.language+abc.science+abc.maths+abc.history
# Out:
# 0    214
# 1    143
# 2    157
# 3    222
# 4    196
# 5    214
# 6    208
# dtype: int64

# %%
abc['total']=abc.language+abc.science+abc.maths+abc.history

# %%
abc
# Out:
#   student  language  science  maths  history  total
# 0   kumar        90       56     34       34    214
# 1   kevin        10       34     32       67    143
# 2   sammy        90       23     12       32    157
# 3  janice        20       67     90       45    222
# 4   peter        30       56     45       65    196
# 5    prem        90       45     45       34    214
# 6  carrol        50       90     45       23    208

# %%
abc=abc.drop('total',axis=1)

# %%
abc
# Out:
#   student  language  science  maths  history
# 0   kumar        90       56     34       34
# 1   kevin        10       34     32       67
# 2   sammy        90       23     12       32
# 3  janice        20       67     90       45
# 4   peter        30       56     45       65
# 5    prem        90       45     45       34
# 6  carrol        50       90     45       23

# %%
abc.science<50
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# 4    False
# 5     True
# 6    False
# Name: science, dtype: bool

# %%
abc[abc.science<50]
# Out:
#   student  language  science  maths  history
# 1   kevin        10       34     32       67
# 2   sammy        90       23     12       32
# 5    prem        90       45     45       34

# %%
len(abc[abc.science<50])
# Out:
# 3

# %%
abc.maths>50
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6    False
# Name: maths, dtype: bool

# %%
abc[abc.maths>50]
# Out:
#   student  language  science  maths  history
# 3  janice        20       67     90       45

# %%
len(abc[abc.maths>50])
# Out:
# 1

# %%
filter=abc.maths>50

# %%
filter1=abc.science<50

# %%
filter & filter1
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# dtype: bool

# %%
abc[filter & filter1]
# Out:
# Empty DataFrame
# Columns: [student, language, science, maths, history]
# Index: []

# %%
abc[filter | filter1]
# Out:
#   student  language  science  maths  history
# 1   kevin        10       34     32       67
# 2   sammy        90       23     12       32
# 3  janice        20       67     90       45
# 5    prem        90       45     45       34

# %%
abc.student.unique()
# Out:
# array(['kumar', 'kevin', 'sammy', 'janice', 'peter', 'prem', 'carrol'],
#       dtype=object)

# %%
abc.student.nunique()
# Out:
# 7

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline
plt.rcParams['figure.figsize']=8,4
import warnings
warnings.filterwarnings('ignore')

# %%
vis=sns.distplot(abc.maths)

# %%
vis1=sns.distplot(abc['maths'],bins=10)

# %%
vis2=sns.lmplot(data=abc,x='science',y='maths')

# %%
vis2=sns.lmplot(data=abc,x='science',y='maths',fit_reg=True)

# %%
vis3=sns.lmplot(data=abc,x='science',y='maths',fit_reg=True,hue='student')

# %%
sns.boxplot(data=abc,x='science',y='history')
# Out:
# <Axes: xlabel='science', ylabel='history'>
